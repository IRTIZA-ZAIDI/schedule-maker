# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/irtiza/Documents/Scheduke maker/schdule formatted.csv',header=0)

# %%
df
# Out:
#                       Timing  \
# 0     8:30 AM \nto \n9:45 AM
# 1     8:30 AM \nto \n9:45 AM
# 2     8:30 AM \nto \n9:45 AM
# 3     8:30 AM \nto \n9:45 AM
# 4     8:30 AM \nto \n9:45 AM
# ...                      ...
# 1118  7:00 PM\n to\n 8:15 PM
# 1119  7:00 PM\n to\n 8:15 PM
# 1120  7:00 PM\n to\n 8:15 PM
# 1121  7:00 PM\n to\n 8:15 PM
# 1122                     NaN
#
#                                             Course Name Class & Program  \
# 0                      Information Security and Ethics           BSCS-8
# 1                                                   NaN             NaN
# 2                           Islamic Schalory Tradition             BSCS
# 3                    Financial Institutions and Markets           BBA-4
# 4                               Institutional Economics  ECO - Elective
# ...                                                 ...             ...
# 1118                                                NaN             NaN
# ...

# %%
print("Column names:", df.columns)
# Out:
# Column names: Index(['Timing', 'Course Name', 'Class & Program', 'Room No.',
#        'UMS Class  No.', 'Teacher', 'Day '],
#       dtype='object')

# %%
def split_timing(timing):
    if pd.notna(timing):  # Check for NaN values
        try:
            # Split the timing string into start and end times
            start, end = timing.replace("\n", "").split("to")
            return start.strip(), end.strip()
        except ValueError:
            # Handle the case where the split operation fails
            print(timing.replace("\n", "").split(" to "))
            return None, None
    else:
        return None, None

# %%
# Apply the split_timing function to create 'Start Time' and 'End Time' columns
df[["Start Time", "End Time"]] = df["Timing"].apply(split_timing).apply(pd.Series)

# %%
# Drop the original 'Timing' column if needed
df = df.drop("Timing", axis=1)

# %%
df.columns
# Out:
# Index(['Course Name', 'Class & Program', 'Room No.', 'UMS Class  No.',
#        'Teacher', 'Day ', 'Start Time', 'End Time'],
#       dtype='object')

# %%
df
# Out:
#                                             Course Name Class & Program  \
# 0                      Information Security and Ethics           BSCS-8
# 1                                                   NaN             NaN
# 2                           Islamic Schalory Tradition             BSCS
# 3                    Financial Institutions and Markets           BBA-4
# 4                               Institutional Economics  ECO - Elective
# ...                                                 ...             ...
# 1118                                                NaN             NaN
# 1119                                                NaN             NaN
# 1120                                                NaN             NaN
# 1121  Parallel and Distributed Computing (Lab) Only ...          BSCS-6
# 1122                                                NaN             NaN
#
#         Room No. UMS Class  No.                   Teacher               Day   \
# ...

# %%
# Drop rows where 'UMS Class No.' column has NaN values
df = df.dropna(subset=["UMS Class  No."])

# %%
# Convert Start Time and End Time to time format
df['Start Time'] = pd.to_datetime(df['Start Time'], format='%I:%M %p').dt.time
df['End Time'] = pd.to_datetime(df['End Time'], format='%I:%M %p').dt.time
# Out:
# /var/folders/g9/64n80gs13d13qhs7rbzhkps00000gn/T/ipykernel_1234/1222454486.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Start Time'] = pd.to_datetime(df['Start Time'], format='%I:%M %p').dt.time
# /var/folders/g9/64n80gs13d13qhs7rbzhkps00000gn/T/ipykernel_1234/1222454486.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['End Time'] = pd.to_datetime(df['End Time'], format='%I:%M %p').dt.time

# %%
df
# Out:
#                                             Course Name Class & Program  \
# 0                      Information Security and Ethics           BSCS-8
# 2                           Islamic Schalory Tradition             BSCS
# 3                    Financial Institutions and Markets           BBA-4
# 4                               Institutional Economics  ECO - Elective
# 5               Fundamentals of Supply Chain Management   MGMT Elective
# ...                                                 ...             ...
# 1073                              Reserved for Graduate             NaN
# 1075  Parallel and Distributed Computing (Lab) Only ...         BSCS-6
# 1085  International Business   (BBA % BSAF)         ...           MGT-E
# 1111  Parallel and Distributed Computing Only Friday...          BSCS-6
# 1121  Parallel and Distributed Computing (Lab) Only ...          BSCS-6
#
#         Room No. UMS Class  No.                   Teacher               Day   \
# ...

# %%
# course_name = "Introduction to Artificial Intelligence"
# ai_courses = df.loc[df["Course Name"] == course_name]
# print(ai_courses.shape[0])
# ai_courses

# %%
# course_name = "Computer Communication & Networking"
# Filter out rows where "Course Name" is not null and contains the specified course name
# ai_courses = df[
#     df["Course Name"].notnull() & df["Course Name"].str.contains(course_name)
# ]
# print(ai_courses.shape[0])
# ai_courses

# %%
# course_name = "Computer Architecture and Assembly Language"
# Filter out rows where "Course Name" is not null and contains the specified course name
# ai_courses = df[
#     df["Course Name"].notnull() & df["Course Name"].str.contains(course_name)
# ]
# print(ai_courses.shape[0])
# ai_courses

# %%
# course_name = "Introduction to Text Analytics"
# ai_courses = df[
#     df["Course Name"].notnull() & df["Course Name"].str.contains(course_name)
# ]
# print(ai_courses.shape[0])
# ai_courses

# %%
# course_name = "Data Warehousing"
# ai_courses = df[
#     df["Course Name"].notnull() & df["Course Name"].str.contains(course_name)
# ]
# print(ai_courses.shape[0])
# ai_courses

# %%
# courses = df[df["UMS Class  No."].notnull() & df["UMS Class  No."].str.contains("71196")]
# courses

# %%
# lab_rows = courses[courses["Course Name"].str.contains("Lab")]
# lab_rows

# %%
# lab_rows = courses[courses["Course Name"].str.contains("Lecture")]
# lab_rows

# %%
# check duplicates ,ifyes: name break find Lab/Lecture : Lab 2

# %%
# Create new columns for lab-related information
df["Labday"] = ""
df["Lab start time"] = ""
df["Lab end time"] = ""
# Out:
# /var/folders/g9/64n80gs13d13qhs7rbzhkps00000gn/T/ipykernel_1234/339628316.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Labday"] = ""
# /var/folders/g9/64n80gs13d13qhs7rbzhkps00000gn/T/ipykernel_1234/339628316.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Lab start time"] = ""
# /var/folders/g9/64n80gs13d13qhs7rbzhkps00000gn/T/ipykernel_1234/339628316.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# Filter rows for the specific course "71196"
# course_df = df[
#     df["UMS Class  No."].notnull() & df["UMS Class  No."].str.contains("71196")
# ]

# for ums_class_code, group_df in course_df[
#     course_df.duplicated("UMS Class  No.", keep=False)
# ].groupby("UMS Class  No."):
    # # Identify rows with "Lab" in the 'Course Name'
    # lab_rows = group_df[group_df["Course Name"].str.contains("Lab")]

    # if not lab_rows.empty:
        # Extract lab-related information
        # lab_day_match = lab_rows["Course Name"].str.extract(r"Only (\w+)")
        # print(lab_day_match)
        # lab_days = ", ".join(lab_day_match[0].unique())
        # print(lab_days)
        # lab_start_time = min(lab_rows[["Start Time", "End Time"]].min(axis=1))
        # print(lab_start_time)
        # lab_end_time = max(lab_rows[["Start Time", "End Time"]].max(axis=1))
        # print(lab_end_time)

        # print(lab_days, lab_start_time, lab_end_time)

        # Update the original DataFrame with lab-related information
        # df.loc[df["UMS Class  No."] == ums_class_code, "Labday"] = lab_days
        # df.loc[df["UMS Class  No."] == ums_class_code, "Lab start time"] = (
        #     lab_start_time
        # )
        # df.loc[df["UMS Class  No."] == ums_class_code, "Lab end time"] = lab_end_time

# Drop duplicate rows keeping the last occurrence
# df = df.drop_duplicates("UMS Class  No.", keep="last")

# Print the updated DataFrame for the specific course "71196"
# df[df["UMS Class  No."].str.contains("71196")]

# %%
null_course_rows = df[df["Course Name"].isnull()]
null_course_rows
# Out:
#      Course Name Class & Program Room No.          UMS Class  No.     Teacher  \
# 599          NaN             NaN   MTC-24                   75353         NaN
# 746          NaN             NaN    MTS 8  Reserved for Graduate          NaN
# 969          NaN         MSCS/DS  MTC-20A                   96033  Mr. Shahab
# 1027         NaN             NaN    MTS 8                   96041         NaN
#
#                   Day  Start Time  End Time Labday Lab start time Lab end time
# 599   Tuesday/Thrusday   14:30:00  15:45:00
# 746   Tuesday/Thrusday   19:00:00  20:15:00
# 969    Friday/Saturday   14:30:00  15:45:00
# 1027   Friday/Saturday   16:00:00  17:15:00

# %%
df = df.dropna(subset=["Course Name"])

# %%
# to check if no important row was removed after the following function
unique_ums_code_sum = df["UMS Class  No."].nunique()
unique_ums_code_sum
# Out:
# 372

# %%
# Initialize counters
affected_rows_count = 0
updated_rows_count = 0

# %%
# Create a new DataFrame to store the updated rows
updated_df = pd.DataFrame(columns=df.columns)

# %%
# Iterate over each UMS Class No.
for ums_class_code, group_df in df[df["UMS Class  No."].notnull()].groupby(
    "UMS Class  No."
):
# Identify rows with "Lab" in the 'Course Name'
lab_rows = group_df[group_df["Course Name"].str.contains("Lab")]

if not lab_rows.empty:  # Use .empty directly
# Extract lab-related information
lab_day_match = lab_rows["Course Name"].str.extract(r"Only (\w+)")
lab_days = ", ".join(lab_day_match[0].dropna().astype(str).unique())
lab_start_time = min(lab_rows[["Start Time", "End Time"]].min(axis=1))
lab_end_time = max(lab_rows[["Start Time", "End Time"]].max(axis=1))

# print(lab_days, lab_start_time, lab_end_time)

Update the original DataFrame with lab-related information
df.loc[df["UMS Class  No."] == ums_class_code, "Labday"] = lab_days
df.loc[df["UMS Class  No."] == ums_class_code, "Lab start time"] = (
    lab_start_time
)
df.loc[df["UMS Class  No."] == ums_class_code, "Lab end time"] = lab_end_time

# Append the updated rows to the new DataFrame
updated_df = pd.concat([updated_df, lab_rows], ignore_index=True)

# Update counters
affected_rows_count += len(group_df)
updated_rows_count += len(lab_rows)
# Out:
#   Cell In[520], line 6
#     lab_rows = group_df[group_df["Course Name"].str.contains("Lab")]
#     ^
# IndentationError: expected an indented block

# %%
# Drop duplicate rows keeping the last occurrence
df = df.drop_duplicates("UMS Class  No.", keep="last")

# %%
# Print summary information
print(f"Total affected rows: {affected_rows_count}")
print(f"Total updated rows: {updated_rows_count}")
# Out:
# Total affected rows: 82
# Total updated rows: 82

# %%
# Display the updated DataFrame
df
# Out:
#                                             Course Name Class & Program  \
# 0                      Information Security and Ethics           BSCS-8
# 2                           Islamic Schalory Tradition             BSCS
# 3                    Financial Institutions and Markets           BBA-4
# 4                               Institutional Economics  ECO - Elective
# 5               Fundamentals of Supply Chain Management   MGMT Elective
# ...                                                 ...             ...
# 1038                         Fundamentals of E-Commerce           MKT-E
# 1073                              Reserved for Graduate             NaN
# 1085  International Business   (BBA % BSAF)         ...           MGT-E
# 1111  Parallel and Distributed Computing Only Friday...          BSCS-6
# 1121  Parallel and Distributed Computing (Lab) Only ...          BSCS-6
#
#         Room No. UMS Class  No.                   Teacher               Day   \
# ...

# %%
# to check if no important row was removed after the following function
unique_ums_code_sum = df["UMS Class  No."].nunique()
unique_ums_code_sum
# 372 equal similar ums code / means dealt well
# Out:
# 372

# %%
# remeber ums code is string
ums_code_95937_rows = df[df["UMS Class  No."] == "95937"]
ums_code_95937_rows
# Out:
#                                             Course Name Class & Program  \
# 1003  Web Based Application Development  Only Friday...     CS Elective
#
#      Room No. UMS Class  No.            Teacher             Day  Start Time  \
# 1003   MCC-15          95937  Mr. Sami Ul Ahbab  Friday/Saturday   16:00:00
#
#       End Time Labday Lab start time Lab end time
# 1003  17:15:00

# %%
web_dev_courses = df[
    df["Course Name"].str.contains(
        "Web Based Application Development  Only Friday", case=False, na=False
    )
]
web_dev_courses
# Out:
#                                             Course Name Class & Program  \
# 1003  Web Based Application Development  Only Friday...     CS Elective
#
#      Room No. UMS Class  No.            Teacher             Day  Start Time  \
# 1003   MCC-15          95937  Mr. Sami Ul Ahbab  Friday/Saturday   16:00:00
#
#       End Time Labday Lab start time Lab end time
# 1003  17:15:00

# %%
updated_df
# Out:
#                                           Course Name Class & Program  \
# 0                      Chinese -II (Lab) Monday Only            BBA-6
# 1                                         Chinese -II           BBA-6
# 2   Computer Architecture and Assembly Language (L...          BSCS-4
# 3   Computer Architecture and Assembly Language (L...          BSCS-4
# 4   Computer Architecture and Assembly Language (L...          BSCS-4
# ..                                                ...             ...
# 77                                   Data Structure            BSCS-3
# 78                     Arabic - I (Lab Tuesday Only )    All programs
# 79                                         Arabic - I    All programs
# 80                      Arabic-II (Lab Tuesday Only )    All programs
# 81                                          Arabic-II    All programs
#
#    Room No. UMS Class  No.                       Teacher               Day   \
# ...
